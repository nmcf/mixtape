# %%
import numpy as np
import pandas as pd
import matplotlib
from ydata_profiling import ProfileReport

# %%
# Load the master dataframe from the pickle we created
master_df = pd.read_pickle('./data/pickles/master_df.pkl')

print(f"Dataset loaded: {master_df.shape[0]:,} rows and {master_df.shape[1]} columns.")
# Out:
# Dataset loaded: 157,945,861 rows and 18 columns.

# %%
def optimize_floats(df):
    floats = df.select_dtypes(include=['float64']).columns
    df[floats] = df[floats].apply(pd.to_numeric, downcast='float')
    return df

def optimize_ints(df):
    ints = df.select_dtypes(include=['int64']).columns
    df[ints] = df[ints].apply(pd.to_numeric, downcast='integer')
    return df

master_df = optimize_floats(master_df)
master_df = optimize_ints(master_df)

# %%
master_df.head()
# Out:
#    album_id                                                gid  \
# 0         2  b'\xe8\xbe\xe7Y\x9e\xfc5\xc2\x93\xd7\t\xac\xe9...
# 1         2  b'\xe8\xbe\xe7Y\x9e\xfc5\xc2\x93\xd7\t\xac\xe9...
# 2         2  b'\xe8\xbe\xe7Y\x9e\xfc5\xc2\x93\xd7\t\xac\xe9...
# 3         2  b'\xe8\xbe\xe7Y\x9e\xfc5\xc2\x93\xd7\t\xac\xe9...
# 4         2  b'\xe8\xbe\xe7Y\x9e\xfc5\xc2\x93\xd7\t\xac\xe9...
#
#           album_name  artist_credit  type_album  album_tag_id  \
# 0  Eclectic Electric              1           1          1186
# 1  Eclectic Electric              1           1          1186
# 2  Eclectic Electric              1           1          1186
# 3  Eclectic Electric              1           1          1186
# 4  Eclectic Electric              1           1          1186
#
#    album_tag_count  album_rating  album_rating_count      artist_name  \
# 0                2           0.0                 0.0  Various Artists
# ...

# %%
# Take a 10-20% random sample
sample_df = master_df.sample(n=20000, random_state=42)

profile = ProfileReport(sample_df, title="Music Master Sample Profile", minimal=True)
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling v4.18.4&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-05-11 10:54:32.325969&quot; name=date&gt;&lt;title&gt;Music Master Sample Profile&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...
